# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/Users/sunyueqian/Desktop/Python Computer Vison/DATA/dog_backpack.jpg')
colorCorrected = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(img)
plt.imshow(colorCorrected)

# %%
flipUpSideDown = cv2.flip(colorCorrected,0)
plt.imshow(flipUpSideDown)

# %%
drawEmptyRectanguler = cv2.rectangle(colorCorrected,pt1=(200,400),pt2=(600,800),color=(255,0,0),thickness=5)
plt.imshow(drawEmptyRectanguler)

# %%
vertices = np.array([[400,400],[200,800],[600,800]],dtype=np.int32)
pts = vertices.reshape((-1,1,2))
#drawTriangle = cv2.polylines(colorCorrected,[pts],isClosed=True,color=(0,0,255),thickness=5)
drawTriangle = cv2.fillPoly(colorCorrected, [pts], color=(0,0,255))
plt.imshow(drawEmptyRectanguler)
